# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Convolution1D,MaxPooling1D,BatchNormalization,Flatten,Dense, Dropout, Activation,LSTM
from keras import optimizers

import os
import numpy as np
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
def lstm(epochs): #reshape필요
    global X,Y,hist
    
    
    X = np.array(X)
    Y = np.array(Y)
    X_=np.reshape(X,[-1,xshape,1])

    X_train, X_test, Y_train, Y_test = train_test_split(X_,Y)

    print(X_.shape)
    
    model = Sequential()
    model.add(LSTM(32, input_shape=(xshape,1)))
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(2,activation='softmax'))
    #model.summary()

    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    hist=model.fit(X_train, Y_train, nb_epoch=epochs,batch_size=20, verbose=2, validation_split=0.1)
    
    test_loss, test_acc = model.evaluate(X_test,  Y_test, verbose=2) #실제 test_data 테스트 결과
    print("LSTM",test_loss, test_acc)
    doplot()

    
def doplot(): #plot함수
    global hist
    plt.plot(hist.history['accuracy'])
    plt.plot(hist.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend([ 'acc', 'val_acc'], loc='upper left')
    plt.show()
    
    plt.plot(hist.history['loss'])
    plt.plot(hist.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['loss', 'val_loss'], loc='upper left')
    plt.show()

# %%
def DA_Jitter(X, sigma=0.075):
    myNoise = np.random.normal(loc=0, scale=sigma, size=X.shape)
    return X+myNoise

'''
def DA_Scaling(X, sigma=0.1):
    scalingFactor = np.random.normal(loc=1.0, scale=sigma, size=(1,X.shape[1])) # shape=(1,3)
    myNoise = np.matmul(np.ones((X.shape[0],1)), scalingFactor)
    return X*myNoise

def GenerateRandomCurves(X, sigma=0.2, knot=4):
    xx = (np.ones((X.shape[1],1))*(np.arange(0,X.shape[0], (X.shape[0]-1)/(knot+1)))).transpose()
    yy = np.random.normal(loc=1.0, scale=sigma, size=(knot+2, X.shape[1]))
    x_range = np.arange(X.shape[0])
    cs_a = CubicSpline(xx[:,0], yy[:,0])
    cs_b = CubicSpline(xx[:,1], yy[:,1])
    cs_c = CubicSpline(xx[:,2], yy[:,2])
    cs_d = CubicSpline(xx[:,3], yy[:,3])
    return np.array([cs_a(x_range),cs_b(x_range),cs_c(x_range),cs_d(x_range)]).transpose()

def DA_MagWarp(X, sigma=0.2):
    return X * GenerateRandomCurves(X, sigma)

def DA_Rotation(X):
    axis = np.random.uniform(low=-1, high=1, size=X.shape[1])
    angle = np.random.uniform(low=-np.pi, high=np.pi)
    return np.matmul(X , axangle2mat(axis,angle))
'''
# Out:
# '\ndef DA_Scaling(X, sigma=0.1):\n    scalingFactor = np.random.normal(loc=1.0, scale=sigma, size=(1,X.shape[1])) # shape=(1,3)\n    myNoise = np.matmul(np.ones((X.shape[0],1)), scalingFactor)\n    return X*myNoise\n\ndef GenerateRandomCurves(X, sigma=0.2, knot=4):\n    xx = (np.ones((X.shape[1],1))*(np.arange(0,X.shape[0], (X.shape[0]-1)/(knot+1)))).transpose()\n    yy = np.random.normal(loc=1.0, scale=sigma, size=(knot+2, X.shape[1]))\n    x_range = np.arange(X.shape[0])\n    cs_a = CubicSpline(xx[:,0], yy[:,0])\n    cs_b = CubicSpline(xx[:,1], yy[:,1])\n    cs_c = CubicSpline(xx[:,2], yy[:,2])\n    cs_d = CubicSpline(xx[:,3], yy[:,3])\n    return np.array([cs_a(x_range),cs_b(x_range),cs_c(x_range),cs_d(x_range)]).transpose()\n\ndef DA_MagWarp(X, sigma=0.2):\n    return X * GenerateRandomCurves(X, sigma)\n\ndef DA_Rotation(X):\n    axis = np.random.uniform(low=-1, high=1, size=X.shape[1])\n    angle = np.random.uniform(low=-np.pi, high=np.pi)\n    return np.matmul(X , axangle2mat(axis,angle))\n'

# %%
#전체용
filepath='./fbcsp_numpy_result/'
num_classes=2 #분류할 클래스 개수
X=[]
Y=[]
for file in os.listdir(filepath):
    if 'data' in file and 'sub8' in file:
        print(file)
        if len(X)==0:
            X=np.load(filepath+file)
        else:
            X1=np.load(filepath+file)
            X=np.concatenate((X,X1),axis=0)
    elif 'label' in file and 'sub8' in file:
        print(file)
        if len(Y)==0:
            Y=np.load(filepath+file)
        else:
            Y1=np.load(filepath+file)
            Y=np.concatenate((Y,Y1),axis=0)

X = np.array(X)
Y = np.array(Y)
print("aug전 ",X.shape,Y.shape)

X=np.concatenate((X,DA_Jitter(X)),axis=0)
#X=np.concatenate((X,DA_Scaling(X)),axis=0)
#X=np.concatenate((X,DA_MagWarp(X)),axis=0) #코드수정필요
#X=np.concatenate((X,DA_Rotation(X)),axis=0) #rotation import해와야함
#Y=np.concatenate((Y,Y),axis=0)
Y=np.concatenate((Y,Y),axis=0)

print("aug후 ",X.shape,Y.shape)

X_train, X_test, Y_train, Y_test = train_test_split(X,Y)
print(X_train.shape, X_test.shape)

xshape=X.shape[1]
hist=1 #global 변수선언용

lstm(300)
# Out:
# sub2_data.npy
# sub2_label.npy
# aug전  (1212, 28) (1212,)
# aug후  (2424, 28) (2424,)
# (1818, 28) (606, 28)
# (2424, 28, 1)
# C:\Users\jaewon\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1636 samples, validate on 182 samples
# Epoch 1/300
#  - 2s - loss: 0.6828 - accuracy: 0.5691 - val_loss: 0.6653 - val_accuracy: 0.6154
# Epoch 2/300
#  - 1s - loss: 0.6441 - accuracy: 0.6449 - val_loss: 0.5951 - val_accuracy: 0.6648
# Epoch 3/300
#  - 1s - loss: 0.5897 - accuracy: 0.6852 - val_loss: 0.5431 - val_accuracy: 0.7253
# Epoch 4/300
#  - 1s - loss: 0.5222 - accuracy: 0.7408 - val_loss: 0.4808 - val_accuracy: 0.7582
# Epoch 5/300
#  - 1s - loss: 0.4801 - accuracy: 0.7787 - val_loss: 0.5000 - val_accuracy: 0.7692
# Epoch 6/300
#  - 1s - loss: 0.4631 - accuracy: 0.7958 - val_loss: 0.4556 - val_accuracy: 0.7857
# Epoch 7/300
#  - 1s - loss: 0.4455 - accuracy: 0.7995 - val_loss: 0.4710 - val_accuracy: 0.7802
# Epoch 8/300
#  - 1s - loss: 0.4510 - accuracy: 0.8020 - val_loss: 0.4691 - val_accuracy: 0.7692
# Epoch 9/300
#  - 1s - loss: 0.4437 - accuracy: 0.8032 - val_loss: 0.4494 - val_accuracy: 0.7802
# Epoch 10/300
#  - 1s - loss: 0.4296 - accuracy: 0.8160 - val_loss: 0.4694 - val_accuracy: 0.7747
# Epoch 11/300
#  - 1s - loss: 0.4222 - accuracy: 0.8099 - val_loss: 0.4425 - val_accuracy: 0.7967
# Epoch 12/300
#  - 1s - loss: 0.4185 - accuracy: 0.8209 - val_loss: 0.4369 - val_accuracy: 0.7802
# Epoch 13/300
#  - 1s - loss: 0.4090 - accuracy: 0.8203 - val_loss: 0.4119 - val_accuracy: 0.8242
# Epoch 14/300
#  - 1s - loss: 0.4061 - accuracy: 0.8307 - val_loss: 0.4324 - val_accuracy: 0.8187
# Epoch 15/300
#  - 1s - loss: 0.3967 - accuracy: 0.8258 - val_loss: 0.4328 - val_accuracy: 0.8132
# Epoch 16/300
#  - 1s - loss: 0.3986 - accuracy: 0.8331 - val_loss: 0.4067 - val_accuracy: 0.8187
# Epoch 17/300
#  - 1s - loss: 0.4077 - accuracy: 0.8221 - val_loss: 0.3950 - val_accuracy: 0.8187
# Epoch 18/300
#  - 1s - loss: 0.3883 - accuracy: 0.8368 - val_loss: 0.3913 - val_accuracy: 0.8352
# Epoch 19/300
#  - 1s - loss: 0.3819 - accuracy: 0.8429 - val_loss: 0.4277 - val_accuracy: 0.8352
# Epoch 20/300
#  - 1s - loss: 0.3783 - accuracy: 0.8313 - val_loss: 0.4057 - val_accuracy: 0.8297
# Epoch 21/300
#  - 1s - loss: 0.3810 - accuracy: 0.8295 - val_loss: 0.4214 - val_accuracy: 0.8132
# Epoch 22/300
#  - 1s - loss: 0.3812 - accuracy: 0.8362 - val_loss: 0.3610 - val_accuracy: 0.8571
# Epoch 23/300
#  - 1s - loss: 0.3736 - accuracy: 0.8362 - val_loss: 0.3537 - val_accuracy: 0.8407
# Epoch 24/300
#  - 1s - loss: 0.3681 - accuracy: 0.8356 - val_loss: 0.3655 - val_accuracy: 0.8297
# Epoch 25/300
#  - 1s - loss: 0.3623 - accuracy: 0.8344 - val_loss: 0.3469 - val_accuracy: 0.8571
# Epoch 26/300
#  - 1s - loss: 0.3582 - accuracy: 0.8472 - val_loss: 0.3938 - val_accuracy: 0.8352
# Epoch 27/300
#  - 1s - loss: 0.3536 - accuracy: 0.8441 - val_loss: 0.3558 - val_accuracy: 0.8462
# Epoch 28/300
#  - 1s - loss: 0.3577 - accuracy: 0.8502 - val_loss: 0.4287 - val_accuracy: 0.8352
# Epoch 29/300
#  - 1s - loss: 0.3649 - accuracy: 0.8405 - val_loss: 0.3326 - val_accuracy: 0.8626
# Epoch 30/300
#  - 1s - loss: 0.3470 - accuracy: 0.8399 - val_loss: 0.3537 - val_accuracy: 0.8626
# Epoch 31/300
#  - 1s - loss: 0.3492 - accuracy: 0.8545 - val_loss: 0.3421 - val_accuracy: 0.8626
# Epoch 32/300
#  - 1s - loss: 0.3376 - accuracy: 0.8551 - val_loss: 0.4210 - val_accuracy: 0.8407
# Epoch 33/300
#  - 1s - loss: 0.3369 - accuracy: 0.8551 - val_loss: 0.3248 - val_accuracy: 0.8846
# Epoch 34/300
#  - 1s - loss: 0.3409 - accuracy: 0.8509 - val_loss: 0.3389 - val_accuracy: 0.8626
# Epoch 35/300
#  - 1s - loss: 0.3294 - accuracy: 0.8631 - val_loss: 0.3395 - val_accuracy: 0.8516
# Epoch 36/300
#  - 1s - loss: 0.3353 - accuracy: 0.8551 - val_loss: 0.3330 - val_accuracy: 0.8626
# Epoch 37/300
#  - 1s - loss: 0.3186 - accuracy: 0.8631 - val_loss: 0.3256 - val_accuracy: 0.8846
# Epoch 38/300
#  - 1s - loss: 0.3205 - accuracy: 0.8594 - val_loss: 0.3111 - val_accuracy: 0.8901
# Epoch 39/300
#  - 1s - loss: 0.3050 - accuracy: 0.8588 - val_loss: 0.2953 - val_accuracy: 0.8846
# Epoch 40/300
#  - 1s - loss: 0.3092 - accuracy: 0.8674 - val_loss: 0.3223 - val_accuracy: 0.8736
# Epoch 41/300
#  - 1s - loss: 0.3102 - accuracy: 0.8637 - val_loss: 0.3279 - val_accuracy: 0.8736
# Epoch 42/300
#  - 1s - loss: 0.2986 - accuracy: 0.8741 - val_loss: 0.2932 - val_accuracy: 0.8736
# Epoch 43/300
#  - 1s - loss: 0.3014 - accuracy: 0.8625 - val_loss: 0.2855 - val_accuracy: 0.8846
# Epoch 44/300
#  - 1s - loss: 0.2933 - accuracy: 0.8729 - val_loss: 0.2938 - val_accuracy: 0.8791
# Epoch 45/300
#  - 1s - loss: 0.2961 - accuracy: 0.8735 - val_loss: 0.3025 - val_accuracy: 0.8681
# Epoch 46/300
#  - 1s - loss: 0.2900 - accuracy: 0.8833 - val_loss: 0.3177 - val_accuracy: 0.8736
# Epoch 47/300
#  - 1s - loss: 0.2788 - accuracy: 0.8710 - val_loss: 0.3000 - val_accuracy: 0.8846
# Epoch 48/300
#  - 1s - loss: 0.2776 - accuracy: 0.8753 - val_loss: 0.2794 - val_accuracy: 0.8791
# Epoch 49/300
#  - 1s - loss: 0.2697 - accuracy: 0.8900 - val_loss: 0.2982 - val_accuracy: 0.8846
# Epoch 50/300
#  - 1s - loss: 0.2703 - accuracy: 0.8759 - val_loss: 0.2992 - val_accuracy: 0.8736
# Epoch 51/300
#  - 1s - loss: 0.2583 - accuracy: 0.8863 - val_loss: 0.2710 - val_accuracy: 0.8956
# Epoch 52/300
#  - 1s - loss: 0.2647 - accuracy: 0.8863 - val_loss: 0.2663 - val_accuracy: 0.8846
# Epoch 53/300
#  - 1s - loss: 0.2532 - accuracy: 0.8924 - val_loss: 0.2835 - val_accuracy: 0.9011
# Epoch 54/300
#  - 1s - loss: 0.2778 - accuracy: 0.8912 - val_loss: 0.2568 - val_accuracy: 0.8901
# Epoch 55/300
#  - 1s - loss: 0.2361 - accuracy: 0.8955 - val_loss: 0.2666 - val_accuracy: 0.8956
# Epoch 56/300
#  - 1s - loss: 0.2470 - accuracy: 0.8998 - val_loss: 0.2860 - val_accuracy: 0.8956
# Epoch 57/300
#  - 1s - loss: 0.2359 - accuracy: 0.8998 - val_loss: 0.2853 - val_accuracy: 0.8681
# Epoch 58/300
#  - 1s - loss: 0.2540 - accuracy: 0.8888 - val_loss: 0.2679 - val_accuracy: 0.8956
# Epoch 59/300
#  - 1s - loss: 0.2331 - accuracy: 0.9028 - val_loss: 0.2704 - val_accuracy: 0.8901
# Epoch 60/300
#  - 1s - loss: 0.2412 - accuracy: 0.8998 - val_loss: 0.2649 - val_accuracy: 0.8846
# Epoch 61/300
#  - 1s - loss: 0.2200 - accuracy: 0.9077 - val_loss: 0.2543 - val_accuracy: 0.8901
# Epoch 62/300
#  - 1s - loss: 0.2224 - accuracy: 0.9114 - val_loss: 0.2540 - val_accuracy: 0.8956
# Epoch 63/300
#  - 1s - loss: 0.2286 - accuracy: 0.9046 - val_loss: 0.2413 - val_accuracy: 0.8956
# Epoch 64/300
#  - 1s - loss: 0.2039 - accuracy: 0.9114 - val_loss: 0.2498 - val_accuracy: 0.9011
# Epoch 65/300
#  - 1s - loss: 0.2080 - accuracy: 0.9053 - val_loss: 0.2760 - val_accuracy: 0.8736
# Epoch 66/300
#  - 1s - loss: 0.2042 - accuracy: 0.9114 - val_loss: 0.2932 - val_accuracy: 0.8846
# Epoch 67/300
#  - 1s - loss: 0.2120 - accuracy: 0.9101 - val_loss: 0.3561 - val_accuracy: 0.8736
# Epoch 68/300
#  - 1s - loss: 0.2111 - accuracy: 0.8998 - val_loss: 0.2679 - val_accuracy: 0.8846
# Epoch 69/300
#  - 1s - loss: 0.2119 - accuracy: 0.9101 - val_loss: 0.2240 - val_accuracy: 0.8956
# Epoch 70/300
#  - 1s - loss: 0.2037 - accuracy: 0.9132 - val_loss: 0.2433 - val_accuracy: 0.9066
# Epoch 71/300
#  - 1s - loss: 0.1874 - accuracy: 0.9218 - val_loss: 0.2335 - val_accuracy: 0.9011
# Epoch 72/300
#  - 1s - loss: 0.1911 - accuracy: 0.9242 - val_loss: 0.2155 - val_accuracy: 0.9011
# Epoch 73/300
#  - 1s - loss: 0.1835 - accuracy: 0.9211 - val_loss: 0.2325 - val_accuracy: 0.9011
# Epoch 74/300
#  - 1s - loss: 0.2015 - accuracy: 0.9224 - val_loss: 0.2235 - val_accuracy: 0.8956
# Epoch 75/300
#  - 1s - loss: 0.1856 - accuracy: 0.9297 - val_loss: 0.2353 - val_accuracy: 0.8901
# Epoch 76/300
#  - 1s - loss: 0.1788 - accuracy: 0.9254 - val_loss: 0.2510 - val_accuracy: 0.9011
# Epoch 77/300
#  - 1s - loss: 0.1783 - accuracy: 0.9230 - val_loss: 0.2225 - val_accuracy: 0.9121
# Epoch 78/300
#  - 1s - loss: 0.1671 - accuracy: 0.9285 - val_loss: 0.2589 - val_accuracy: 0.8901
# Epoch 79/300
#  - 1s - loss: 0.1785 - accuracy: 0.9236 - val_loss: 0.2522 - val_accuracy: 0.8901
# Epoch 80/300
#  - 1s - loss: 0.1712 - accuracy: 0.9242 - val_loss: 0.2140 - val_accuracy: 0.9066
# Epoch 81/300
#  - 1s - loss: 0.1669 - accuracy: 0.9322 - val_loss: 0.2910 - val_accuracy: 0.8736
# Epoch 82/300
#  - 1s - loss: 0.1661 - accuracy: 0.9297 - val_loss: 0.2723 - val_accuracy: 0.9066
# Epoch 83/300
#  - 1s - loss: 0.1539 - accuracy: 0.9419 - val_loss: 0.2176 - val_accuracy: 0.9341
# Epoch 84/300
#  - 1s - loss: 0.1578 - accuracy: 0.9291 - val_loss: 0.2744 - val_accuracy: 0.9066
# Epoch 85/300
#  - 1s - loss: 0.1608 - accuracy: 0.9309 - val_loss: 0.2180 - val_accuracy: 0.9231
# Epoch 86/300
#  - 1s - loss: 0.1471 - accuracy: 0.9413 - val_loss: 0.2237 - val_accuracy: 0.9231
# Epoch 87/300
#  - 1s - loss: 0.1540 - accuracy: 0.9297 - val_loss: 0.2626 - val_accuracy: 0.8956
# Epoch 88/300
#  - 1s - loss: 0.1366 - accuracy: 0.9425 - val_loss: 0.2316 - val_accuracy: 0.9176
# Epoch 89/300
#  - 1s - loss: 0.1531 - accuracy: 0.9370 - val_loss: 0.3987 - val_accuracy: 0.9066
# Epoch 90/300
#  - 1s - loss: 0.1684 - accuracy: 0.9334 - val_loss: 0.2057 - val_accuracy: 0.9286
# Epoch 91/300
#  - 1s - loss: 0.1312 - accuracy: 0.9517 - val_loss: 0.2440 - val_accuracy: 0.9231
# Epoch 92/300
#  - 1s - loss: 0.1328 - accuracy: 0.9517 - val_loss: 0.2143 - val_accuracy: 0.9286
# Epoch 93/300
#  - 1s - loss: 0.1335 - accuracy: 0.9456 - val_loss: 0.2972 - val_accuracy: 0.8956
# Epoch 94/300
#  - 1s - loss: 0.1477 - accuracy: 0.9395 - val_loss: 0.2258 - val_accuracy: 0.9176
# Epoch 95/300
#  - 1s - loss: 0.1275 - accuracy: 0.9505 - val_loss: 0.2811 - val_accuracy: 0.9176
# Epoch 96/300
#  - 1s - loss: 0.1137 - accuracy: 0.9566 - val_loss: 0.2274 - val_accuracy: 0.9286
# Epoch 97/300
#  - 1s - loss: 0.1073 - accuracy: 0.9597 - val_loss: 0.2267 - val_accuracy: 0.9231
# Epoch 98/300
#  - 1s - loss: 0.1083 - accuracy: 0.9584 - val_loss: 0.2742 - val_accuracy: 0.9231
# Epoch 99/300
#  - 1s - loss: 0.1240 - accuracy: 0.9584 - val_loss: 0.2327 - val_accuracy: 0.9231
# Epoch 100/300
#  - 1s - loss: 0.1212 - accuracy: 0.9517 - val_loss: 0.2018 - val_accuracy: 0.9176
# Epoch 101/300
#  - 1s - loss: 0.1085 - accuracy: 0.9597 - val_loss: 0.2490 - val_accuracy: 0.9286
# Epoch 102/300
#  - 1s - loss: 0.1103 - accuracy: 0.9535 - val_loss: 0.2826 - val_accuracy: 0.9231
# Epoch 103/300
#  - 1s - loss: 0.0981 - accuracy: 0.9609 - val_loss: 0.2413 - val_accuracy: 0.9231
# Epoch 104/300
#  - 1s - loss: 0.0950 - accuracy: 0.9652 - val_loss: 0.1939 - val_accuracy: 0.9341
# Epoch 105/300
#  - 1s - loss: 0.1165 - accuracy: 0.9554 - val_loss: 0.2522 - val_accuracy: 0.9176
# Epoch 106/300
#  - 1s - loss: 0.1038 - accuracy: 0.9584 - val_loss: 0.2165 - val_accuracy: 0.9396
# Epoch 107/300
#  - 1s - loss: 0.0992 - accuracy: 0.9597 - val_loss: 0.2506 - val_accuracy: 0.9231
# Epoch 108/300
#  - 1s - loss: 0.1710 - accuracy: 0.9401 - val_loss: 0.2161 - val_accuracy: 0.9341
# Epoch 109/300
#  - 1s - loss: 0.0997 - accuracy: 0.9633 - val_loss: 0.2604 - val_accuracy: 0.9231
# Epoch 110/300
#  - 1s - loss: 0.0898 - accuracy: 0.9658 - val_loss: 0.1628 - val_accuracy: 0.9505
# Epoch 111/300
#  - 1s - loss: 0.0785 - accuracy: 0.9694 - val_loss: 0.2081 - val_accuracy: 0.9396
# Epoch 112/300
#  - 1s - loss: 0.0716 - accuracy: 0.9774 - val_loss: 0.2174 - val_accuracy: 0.9396
# Epoch 113/300
#  - 1s - loss: 0.0725 - accuracy: 0.9707 - val_loss: 0.2684 - val_accuracy: 0.9286
# Epoch 114/300
#  - 1s - loss: 0.0750 - accuracy: 0.9725 - val_loss: 0.2385 - val_accuracy: 0.9396
# Epoch 115/300
#  - 1s - loss: 0.0782 - accuracy: 0.9737 - val_loss: 0.2203 - val_accuracy: 0.9396
# Epoch 116/300
#  - 1s - loss: 0.0612 - accuracy: 0.9762 - val_loss: 0.2552 - val_accuracy: 0.9286
# Epoch 117/300
#  - 1s - loss: 0.0717 - accuracy: 0.9707 - val_loss: 0.2670 - val_accuracy: 0.9341
# Epoch 118/300
#  - 1s - loss: 0.0850 - accuracy: 0.9700 - val_loss: 0.2772 - val_accuracy: 0.9341
# Epoch 119/300
#  - 1s - loss: 0.0749 - accuracy: 0.9725 - val_loss: 0.2383 - val_accuracy: 0.9396
# Epoch 120/300
#  - 1s - loss: 0.0662 - accuracy: 0.9737 - val_loss: 0.2360 - val_accuracy: 0.9341
# Epoch 121/300
#  - 1s - loss: 0.0700 - accuracy: 0.9737 - val_loss: 0.3250 - val_accuracy: 0.9286
# Epoch 122/300
#  - 1s - loss: 0.0569 - accuracy: 0.9780 - val_loss: 0.2276 - val_accuracy: 0.9505
# Epoch 123/300
#  - 1s - loss: 0.0470 - accuracy: 0.9817 - val_loss: 0.2453 - val_accuracy: 0.9286
# Epoch 124/300
#  - 1s - loss: 0.0447 - accuracy: 0.9841 - val_loss: 0.2399 - val_accuracy: 0.9451
# Epoch 125/300
#  - 1s - loss: 0.0453 - accuracy: 0.9835 - val_loss: 0.2564 - val_accuracy: 0.9286
# Epoch 126/300
#  - 1s - loss: 0.0584 - accuracy: 0.9768 - val_loss: 0.2922 - val_accuracy: 0.9231
# Epoch 127/300
#  - 1s - loss: 0.0925 - accuracy: 0.9688 - val_loss: 0.2243 - val_accuracy: 0.9231
# Epoch 128/300
#  - 1s - loss: 0.0873 - accuracy: 0.9676 - val_loss: 0.1858 - val_accuracy: 0.9176
# Epoch 129/300
#  - 1s - loss: 0.0484 - accuracy: 0.9792 - val_loss: 0.1921 - val_accuracy: 0.9505
# Epoch 130/300
#  - 1s - loss: 0.0611 - accuracy: 0.9774 - val_loss: 0.1552 - val_accuracy: 0.9615
# Epoch 131/300
#  - 1s - loss: 0.0746 - accuracy: 0.9743 - val_loss: 0.1661 - val_accuracy: 0.9505
# Epoch 132/300
#  - 1s - loss: 0.0443 - accuracy: 0.9841 - val_loss: 0.2693 - val_accuracy: 0.9396
# Epoch 133/300
#  - 1s - loss: 0.0411 - accuracy: 0.9878 - val_loss: 0.2391 - val_accuracy: 0.9286
# Epoch 134/300
#  - 1s - loss: 0.0417 - accuracy: 0.9847 - val_loss: 0.1990 - val_accuracy: 0.9505
# Epoch 135/300
#  - 1s - loss: 0.0437 - accuracy: 0.9853 - val_loss: 0.2367 - val_accuracy: 0.9505
# Epoch 136/300
#  - 1s - loss: 0.0395 - accuracy: 0.9829 - val_loss: 0.2737 - val_accuracy: 0.9341
# Epoch 137/300
#  - 1s - loss: 0.0490 - accuracy: 0.9847 - val_loss: 0.2858 - val_accuracy: 0.9286
# Epoch 138/300
#  - 1s - loss: 0.0454 - accuracy: 0.9792 - val_loss: 0.2827 - val_accuracy: 0.9451
# Epoch 139/300
#  - 1s - loss: 0.0491 - accuracy: 0.9823 - val_loss: 0.2207 - val_accuracy: 0.9451
# Epoch 140/300
#  - 1s - loss: 0.0433 - accuracy: 0.9829 - val_loss: 0.2393 - val_accuracy: 0.9505
# Epoch 141/300
#  - 1s - loss: 0.0284 - accuracy: 0.9908 - val_loss: 0.3512 - val_accuracy: 0.9231
# Epoch 142/300
#  - 1s - loss: 0.0441 - accuracy: 0.9823 - val_loss: 0.2522 - val_accuracy: 0.9560
# Epoch 143/300
#  - 1s - loss: 0.0411 - accuracy: 0.9847 - val_loss: 0.2586 - val_accuracy: 0.9505
# Epoch 144/300
#  - 1s - loss: 0.0249 - accuracy: 0.9902 - val_loss: 0.2258 - val_accuracy: 0.9451
# Epoch 145/300
#  - 1s - loss: 0.0885 - accuracy: 0.9682 - val_loss: 0.2884 - val_accuracy: 0.9286
# Epoch 146/300
#  - 1s - loss: 0.0450 - accuracy: 0.9841 - val_loss: 0.2312 - val_accuracy: 0.9286
# Epoch 147/300
#  - 1s - loss: 0.0281 - accuracy: 0.9921 - val_loss: 0.2362 - val_accuracy: 0.9451
# Epoch 148/300
#  - 1s - loss: 0.0388 - accuracy: 0.9817 - val_loss: 0.3624 - val_accuracy: 0.9286
# Epoch 149/300
#  - 1s - loss: 0.0443 - accuracy: 0.9811 - val_loss: 0.2939 - val_accuracy: 0.9396
# Epoch 150/300
#  - 1s - loss: 0.0347 - accuracy: 0.9866 - val_loss: 0.2832 - val_accuracy: 0.9341
# Epoch 151/300
#  - 1s - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.2066 - val_accuracy: 0.9615
# Epoch 152/300
#  - 1s - loss: 0.0253 - accuracy: 0.9884 - val_loss: 0.3585 - val_accuracy: 0.9396
# Epoch 153/300
#  - 1s - loss: 0.0283 - accuracy: 0.9872 - val_loss: 0.3154 - val_accuracy: 0.9286
# Epoch 154/300
#  - 1s - loss: 0.0287 - accuracy: 0.9896 - val_loss: 0.3570 - val_accuracy: 0.9231
# Epoch 155/300
#  - 1s - loss: 0.0451 - accuracy: 0.9835 - val_loss: 0.2948 - val_accuracy: 0.9341
# Epoch 156/300
#  - 1s - loss: 0.0936 - accuracy: 0.9713 - val_loss: 0.3016 - val_accuracy: 0.9505
# Epoch 157/300
#  - 1s - loss: 0.0341 - accuracy: 0.9902 - val_loss: 0.2867 - val_accuracy: 0.9396
# Epoch 158/300
#  - 1s - loss: 0.0209 - accuracy: 0.9921 - val_loss: 0.2706 - val_accuracy: 0.9396
# Epoch 159/300
#  - 1s - loss: 0.0181 - accuracy: 0.9945 - val_loss: 0.2494 - val_accuracy: 0.9396
# Epoch 160/300
#  - 1s - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.2616 - val_accuracy: 0.9286
# Epoch 161/300
#  - 1s - loss: 0.0124 - accuracy: 0.9976 - val_loss: 0.2592 - val_accuracy: 0.9396
# Epoch 162/300
#  - 1s - loss: 0.0226 - accuracy: 0.9921 - val_loss: 0.3019 - val_accuracy: 0.9505
# Epoch 163/300
#  - 1s - loss: 0.0451 - accuracy: 0.9823 - val_loss: 0.3085 - val_accuracy: 0.9396
# Epoch 164/300
#  - 1s - loss: 0.0289 - accuracy: 0.9872 - val_loss: 0.2993 - val_accuracy: 0.9505
# Epoch 165/300
#  - 1s - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.2677 - val_accuracy: 0.9560
# Epoch 166/300
#  - 1s - loss: 0.0547 - accuracy: 0.9841 - val_loss: 0.4119 - val_accuracy: 0.9286
# Epoch 167/300
#  - 1s - loss: 0.0399 - accuracy: 0.9847 - val_loss: 0.3232 - val_accuracy: 0.9011
# Epoch 168/300
#  - 1s - loss: 0.0370 - accuracy: 0.9902 - val_loss: 0.3509 - val_accuracy: 0.9121
# Epoch 169/300
#  - 1s - loss: 0.0342 - accuracy: 0.9878 - val_loss: 0.2164 - val_accuracy: 0.9560
# Epoch 170/300
#  - 1s - loss: 0.0297 - accuracy: 0.9902 - val_loss: 0.3186 - val_accuracy: 0.9176
# Epoch 171/300
#  - 1s - loss: 0.0247 - accuracy: 0.9902 - val_loss: 0.2882 - val_accuracy: 0.9341
# Epoch 172/300
#  - 1s - loss: 0.0154 - accuracy: 0.9951 - val_loss: 0.2675 - val_accuracy: 0.9396
# Epoch 173/300
#  - 1s - loss: 0.0230 - accuracy: 0.9921 - val_loss: 0.2433 - val_accuracy: 0.9176
# Epoch 174/300
#  - 1s - loss: 0.0810 - accuracy: 0.9694 - val_loss: 0.3125 - val_accuracy: 0.9341
# Epoch 175/300
#  - 1s - loss: 0.0226 - accuracy: 0.9908 - val_loss: 0.2744 - val_accuracy: 0.9396
# Epoch 176/300
#  - 1s - loss: 0.0124 - accuracy: 0.9969 - val_loss: 0.2851 - val_accuracy: 0.9341
# Epoch 177/300
#  - 1s - loss: 0.0087 - accuracy: 0.9982 - val_loss: 0.3323 - val_accuracy: 0.9341
# Epoch 178/300
#  - 1s - loss: 0.0113 - accuracy: 0.9976 - val_loss: 0.3286 - val_accuracy: 0.9231
# Epoch 179/300
#  - 1s - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.3233 - val_accuracy: 0.9396
# Epoch 180/300
#  - 1s - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.2842 - val_accuracy: 0.9341
# Epoch 181/300
#  - 1s - loss: 0.0206 - accuracy: 0.9902 - val_loss: 0.2945 - val_accuracy: 0.9396
# Epoch 182/300
#  - 1s - loss: 0.0160 - accuracy: 0.9939 - val_loss: 0.2403 - val_accuracy: 0.9505
# Epoch 183/300
#  - 1s - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.2594 - val_accuracy: 0.9341
# Epoch 184/300
#  - 1s - loss: 0.0267 - accuracy: 0.9914 - val_loss: 0.2754 - val_accuracy: 0.9396
# Epoch 185/300
#  - 1s - loss: 0.0556 - accuracy: 0.9786 - val_loss: 0.3486 - val_accuracy: 0.9286
# Epoch 186/300
#  - 1s - loss: 0.0586 - accuracy: 0.9835 - val_loss: 0.2936 - val_accuracy: 0.9231
# Epoch 187/300
#  - 1s - loss: 0.0153 - accuracy: 0.9951 - val_loss: 0.1977 - val_accuracy: 0.9505
# Epoch 188/300
#  - 1s - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.2037 - val_accuracy: 0.9451
# Epoch 189/300
#  - 1s - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.1897 - val_accuracy: 0.9560
# Epoch 190/300
#  - 1s - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.1985 - val_accuracy: 0.9451
# Epoch 191/300
#  - 1s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2126 - val_accuracy: 0.9451
# Epoch 192/300
#  - 1s - loss: 0.0173 - accuracy: 0.9951 - val_loss: 0.2879 - val_accuracy: 0.9451
# Epoch 193/300
#  - 1s - loss: 0.0266 - accuracy: 0.9884 - val_loss: 0.3259 - val_accuracy: 0.9396
# Epoch 194/300
#  - 1s - loss: 0.0168 - accuracy: 0.9939 - val_loss: 0.2925 - val_accuracy: 0.9176
# Epoch 195/300
#  - 1s - loss: 0.0726 - accuracy: 0.9768 - val_loss: 0.2374 - val_accuracy: 0.9451
# Epoch 196/300
#  - 1s - loss: 0.0614 - accuracy: 0.9823 - val_loss: 0.4312 - val_accuracy: 0.9066
# Epoch 197/300
#  - 1s - loss: 0.0491 - accuracy: 0.9859 - val_loss: 0.3211 - val_accuracy: 0.9341
# Epoch 198/300
#  - 1s - loss: 0.0329 - accuracy: 0.9884 - val_loss: 0.1888 - val_accuracy: 0.9505
# Epoch 199/300
#  - 1s - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.2666 - val_accuracy: 0.9505
# Epoch 200/300
#  - 1s - loss: 0.0118 - accuracy: 0.9951 - val_loss: 0.2412 - val_accuracy: 0.9451
# Epoch 201/300
#  - 1s - loss: 0.0060 - accuracy: 0.9994 - val_loss: 0.2568 - val_accuracy: 0.9341
# Epoch 202/300
#  - 1s - loss: 0.0084 - accuracy: 0.9976 - val_loss: 0.3254 - val_accuracy: 0.9176
# Epoch 203/300
#  - 1s - loss: 0.0150 - accuracy: 0.9927 - val_loss: 0.2627 - val_accuracy: 0.9396
# Epoch 204/300
#  - 1s - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.2431 - val_accuracy: 0.9560
# Epoch 205/300
#  - 1s - loss: 0.0108 - accuracy: 0.9957 - val_loss: 0.2750 - val_accuracy: 0.9396
# Epoch 206/300
#  - 1s - loss: 0.0080 - accuracy: 0.9969 - val_loss: 0.2830 - val_accuracy: 0.9396
# Epoch 207/300
#  - 1s - loss: 0.0065 - accuracy: 0.9969 - val_loss: 0.2527 - val_accuracy: 0.9560
# Epoch 208/300
#  - 1s - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.2621 - val_accuracy: 0.9560
# Epoch 209/300
#  - 1s - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.2711 - val_accuracy: 0.9451
# Epoch 210/300
#  - 1s - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.3046 - val_accuracy: 0.9505
# Epoch 211/300
#  - 1s - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.3360 - val_accuracy: 0.9451
# Epoch 212/300
#  - 1s - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.2862 - val_accuracy: 0.9451
# Epoch 213/300
#  - 1s - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.3551 - val_accuracy: 0.9286
# Epoch 214/300
#  - 1s - loss: 0.0692 - accuracy: 0.9804 - val_loss: 0.3081 - val_accuracy: 0.9341
# Epoch 215/300
#  - 1s - loss: 0.0666 - accuracy: 0.9817 - val_loss: 0.1708 - val_accuracy: 0.9396
# Epoch 216/300
#  - 1s - loss: 0.0270 - accuracy: 0.9908 - val_loss: 0.3569 - val_accuracy: 0.9121
# Epoch 217/300
#  - 1s - loss: 0.0385 - accuracy: 0.9872 - val_loss: 0.2040 - val_accuracy: 0.9451
# Epoch 218/300
#  - 1s - loss: 0.0390 - accuracy: 0.9878 - val_loss: 0.3533 - val_accuracy: 0.9451
# Epoch 219/300
#  - 1s - loss: 0.0158 - accuracy: 0.9957 - val_loss: 0.2373 - val_accuracy: 0.9451
# Epoch 220/300
#  - 1s - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.1909 - val_accuracy: 0.9670
# Epoch 221/300
#  - 1s - loss: 0.0092 - accuracy: 0.9963 - val_loss: 0.3646 - val_accuracy: 0.9341
# Epoch 222/300
#  - 1s - loss: 0.0091 - accuracy: 0.9963 - val_loss: 0.4028 - val_accuracy: 0.9396
# Epoch 223/300
#  - 1s - loss: 0.0062 - accuracy: 0.9994 - val_loss: 0.2873 - val_accuracy: 0.9451
# Epoch 224/300
#  - 1s - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.4443 - val_accuracy: 0.9396
# Epoch 225/300
#  - 1s - loss: 0.0518 - accuracy: 0.9786 - val_loss: 0.3379 - val_accuracy: 0.9286
# Epoch 226/300
#  - 1s - loss: 0.0199 - accuracy: 0.9933 - val_loss: 0.2534 - val_accuracy: 0.9451
# Epoch 227/300
#  - 1s - loss: 0.0089 - accuracy: 0.9976 - val_loss: 0.2819 - val_accuracy: 0.9560
# Epoch 228/300
#  - 1s - loss: 0.0094 - accuracy: 0.9969 - val_loss: 0.2822 - val_accuracy: 0.9505
# Epoch 229/300
#  - 1s - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.2960 - val_accuracy: 0.9396
# Epoch 230/300
#  - 1s - loss: 0.0062 - accuracy: 0.9963 - val_loss: 0.3245 - val_accuracy: 0.9341
# Epoch 231/300
#  - 1s - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.4395 - val_accuracy: 0.9396
# Epoch 232/300
#  - 1s - loss: 0.0091 - accuracy: 0.9976 - val_loss: 0.5541 - val_accuracy: 0.9231
# Epoch 233/300
#  - 1s - loss: 0.0740 - accuracy: 0.9798 - val_loss: 0.2867 - val_accuracy: 0.9231
# Epoch 234/300
#  - 1s - loss: 0.0846 - accuracy: 0.9731 - val_loss: 0.2792 - val_accuracy: 0.9286
# Epoch 235/300
#  - 1s - loss: 0.0208 - accuracy: 0.9914 - val_loss: 0.2466 - val_accuracy: 0.9505
# Epoch 236/300
#  - 1s - loss: 0.0079 - accuracy: 0.9982 - val_loss: 0.2650 - val_accuracy: 0.9451
# Epoch 237/300
#  - 1s - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.2751 - val_accuracy: 0.9505
# Epoch 238/300
#  - 1s - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.3282 - val_accuracy: 0.9396
# Epoch 239/300
#  - 1s - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.2783 - val_accuracy: 0.9451
# Epoch 240/300
#  - 1s - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.3095 - val_accuracy: 0.9451
# Epoch 241/300
#  - 1s - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.3186 - val_accuracy: 0.9451
# Epoch 242/300
#  - 1s - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.3692 - val_accuracy: 0.9451
# Epoch 243/300
#  - 1s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3276 - val_accuracy: 0.9451
# Epoch 244/300
#  - 1s - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.3578 - val_accuracy: 0.9451
# Epoch 245/300
#  - 1s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.3402 - val_accuracy: 0.9451
# Epoch 246/300
#  - 1s - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.3016 - val_accuracy: 0.9505
# Epoch 247/300
#  - 1s - loss: 0.0054 - accuracy: 0.9969 - val_loss: 0.2891 - val_accuracy: 0.9505
# Epoch 248/300
#  - 1s - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.2807 - val_accuracy: 0.9560
# Epoch 249/300
#  - 1s - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.2913 - val_accuracy: 0.9560
# Epoch 250/300
#  - 1s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3004 - val_accuracy: 0.9505
# Epoch 251/300
#  - 1s - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.4311 - val_accuracy: 0.9176
# Epoch 252/300
#  - 1s - loss: 0.0221 - accuracy: 0.9945 - val_loss: 0.2718 - val_accuracy: 0.9560
# Epoch 253/300
#  - 1s - loss: 0.1011 - accuracy: 0.9762 - val_loss: 0.4018 - val_accuracy: 0.9286
# Epoch 254/300
#  - 1s - loss: 0.0193 - accuracy: 0.9914 - val_loss: 0.1843 - val_accuracy: 0.9505
# Epoch 255/300
#  - 1s - loss: 0.0175 - accuracy: 0.9927 - val_loss: 0.2928 - val_accuracy: 0.9451
# Epoch 256/300
#  - 1s - loss: 0.0243 - accuracy: 0.9933 - val_loss: 0.2934 - val_accuracy: 0.9341
# Epoch 257/300
#  - 1s - loss: 0.0242 - accuracy: 0.9939 - val_loss: 0.2753 - val_accuracy: 0.9451
# Epoch 258/300
#  - 2s - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.1831 - val_accuracy: 0.9560
# Epoch 259/300
#  - 1s - loss: 0.0125 - accuracy: 0.9963 - val_loss: 0.3146 - val_accuracy: 0.9396
# Epoch 260/300
#  - 1s - loss: 0.0270 - accuracy: 0.9914 - val_loss: 0.5471 - val_accuracy: 0.9066
# Epoch 261/300
#  - 1s - loss: 0.0524 - accuracy: 0.9884 - val_loss: 0.2865 - val_accuracy: 0.9341
# Epoch 262/300
#  - 1s - loss: 0.0150 - accuracy: 0.9957 - val_loss: 0.2978 - val_accuracy: 0.9451
# Epoch 263/300
#  - 1s - loss: 0.0218 - accuracy: 0.9927 - val_loss: 0.1595 - val_accuracy: 0.9615
# Epoch 264/300
#  - 1s - loss: 0.0075 - accuracy: 0.9988 - val_loss: 0.2613 - val_accuracy: 0.9396
# Epoch 265/300
#  - 1s - loss: 0.0058 - accuracy: 0.9994 - val_loss: 0.2201 - val_accuracy: 0.9451
# Epoch 266/300
#  - 1s - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.2731 - val_accuracy: 0.9396
# Epoch 267/300
#  - 1s - loss: 0.0052 - accuracy: 0.9976 - val_loss: 0.3602 - val_accuracy: 0.9341
# Epoch 268/300
#  - 1s - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.2397 - val_accuracy: 0.9451
# Epoch 269/300
#  - 1s - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.2771 - val_accuracy: 0.9396
# Epoch 270/300
#  - 1s - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.3056 - val_accuracy: 0.9396
# Epoch 271/300
#  - 1s - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.3076 - val_accuracy: 0.9451
# Epoch 272/300
#  - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9505
# Epoch 273/300
#  - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.3168 - val_accuracy: 0.9451
# Epoch 274/300
#  - 1s - loss: 0.0322 - accuracy: 0.9884 - val_loss: 0.5754 - val_accuracy: 0.9231
# Epoch 275/300
#  - 1s - loss: 0.0991 - accuracy: 0.9756 - val_loss: 0.2474 - val_accuracy: 0.9396
# Epoch 276/300
#  - 1s - loss: 0.0271 - accuracy: 0.9908 - val_loss: 0.3034 - val_accuracy: 0.9396
# Epoch 277/300
#  - 1s - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.2134 - val_accuracy: 0.9560
# Epoch 278/300
#  - 1s - loss: 0.0144 - accuracy: 0.9957 - val_loss: 0.3055 - val_accuracy: 0.9341
# Epoch 279/300
#  - 1s - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.2440 - val_accuracy: 0.9451
# Epoch 280/300
#  - 1s - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.2758 - val_accuracy: 0.9451
# Epoch 281/300
#  - 1s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2844 - val_accuracy: 0.9396
# Epoch 282/300
#  - 1s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2776 - val_accuracy: 0.9451
# Epoch 283/300
#  - 1s - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.2910 - val_accuracy: 0.9451
# Epoch 284/300
#  - 1s - loss: 0.0029 - accuracy: 0.9994 - val_loss: 0.2775 - val_accuracy: 0.9451
# Epoch 285/300
#  - 1s - loss: 8.7131e-04 - accuracy: 1.0000 - val_loss: 0.2697 - val_accuracy: 0.9505
# Epoch 286/300
#  - 1s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3074 - val_accuracy: 0.9451
# Epoch 287/300
#  - 1s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2955 - val_accuracy: 0.9451
# Epoch 288/300
#  - 1s - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.2179 - val_accuracy: 0.9560
# Epoch 289/300
#  - 1s - loss: 0.0350 - accuracy: 0.9872 - val_loss: 0.3253 - val_accuracy: 0.9286
# Epoch 290/300
#  - 1s - loss: 0.0461 - accuracy: 0.9835 - val_loss: 0.2466 - val_accuracy: 0.9505
# Epoch 291/300
#  - 1s - loss: 0.0290 - accuracy: 0.9896 - val_loss: 0.1619 - val_accuracy: 0.9725
# Epoch 292/300
#  - 1s - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.3047 - val_accuracy: 0.9396
# Epoch 293/300
#  - 1s - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.2520 - val_accuracy: 0.9505
# Epoch 294/300
#  - 1s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.2696 - val_accuracy: 0.9341
# Epoch 295/300
#  - 1s - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.3154 - val_accuracy: 0.9396
# Epoch 296/300
#  - 1s - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.3521 - val_accuracy: 0.9396
# Epoch 297/300
#  - 1s - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.3862 - val_accuracy: 0.9341
# Epoch 298/300
#  - 1s - loss: 0.0067 - accuracy: 0.9976 - val_loss: 0.4674 - val_accuracy: 0.9231
# Epoch 299/300
#  - 1s - loss: 0.0276 - accuracy: 0.9921 - val_loss: 0.3214 - val_accuracy: 0.9176
# Epoch 300/300
#  - 1s - loss: 0.0341 - accuracy: 0.9908 - val_loss: 0.2636 - val_accuracy: 0.9231
# LSTM 0.34205298342437734 0.9372937083244324
